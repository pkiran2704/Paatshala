# %% [markdown]
# Setting up the environment

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Read the dataset to python environment.

# %%
data = pd.read_excel(r'/content/gdrive/My Drive/Data Analytics Course/iris.xls')

# %% [markdown]
# Display the columns in the dataset.

# %%
data.columns #prints all columns as a list
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# Calculate the mean of each column of the dataset

# %%
mean_SL = data["SL"].mean()
mean_SW = data["SW"].mean()
mean_PL = data["PL"].mean()
mean_PW = data["PW"].mean()
print("Mean of SL:",mean_SL, "\nMean of SW:", mean_SW, "\nMean of PL:", mean_PL, "\nMean of PW:", mean_PW)
# Out:
# Mean of SL: 5.843333333333334
# Mean of SW: 3.0540000000000003
# Mean of PL: 3.758666666666666
# Mean of PW: 1.1986666666666668

# %% [markdown]
# Check for the null values present in the dataset.

# %%
data.isnull() #isnull() display True if the data is null
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum() #isnull().sum() will give the total number of nulls.
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
sns.pairplot(data)
plt.show()

# %%
plt.hist(data['Classification'], color='purple')
plt.title('Classification vs Frequency',fontweight='bold')
plt.xlabel('Classification',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data)
plt.show()
